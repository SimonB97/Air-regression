# %%
import pandas as pd
import orga_functions as org
import functions as func
import json

# %% [markdown]
# # A) Step by Step - Example

# %% [markdown]
# ## I) Importing JSON File  as Dataframe

# %%
new_df = func.json_to_df("02_LiveData_all.json")

# %%
new_df
# Out:
#          Date      Time   CO(GT) PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  07/02/2005  00.00.00     0.15        1066     870.0     25.87
# 1  07/02/2005  01.00.00  -236.98        1993     -96.0     46.68
# 2  07/02/2005  02.00.00  2330.12         944    2672.0     49.34
# 3  07/02/2005  03.00.00     6.97         165    3989.0   -117.99
# 4  07/02/2005  04.00.00     3.47        1406       NaN       NaN
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx) NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         2040.0    392.0         739.0     151        2508.0       2022.0
# 1          343.0    703.0         217.0     152        -226.0       1979.0
# 2         3339.0    230.0        3738.0     114        4780.0        755.0
# 3         1103.0   1920.0         402.0     -50        3850.0        -30.0
# 4            NaN      NaN           NaN      53           NaN          NaN
#
#          T      RH       AH
# 0    38.67   72.55     2.22
# 1   -67.64   60.83  -154.26
# 2  4603.73   86.45  1215.30
# ...

# %% [markdown]
# ## II) Correction of the datetime

# %%
func.df_correct_datetime(new_df)
# Out:
#                  Date   CO(GT) PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0 2005-02-07 00:00:00     0.15        1066     870.0     25.87         2040.0
# 1 2005-02-07 01:00:00  -236.98        1993     -96.0     46.68          343.0
# 2 2005-02-07 02:00:00  2330.12         944    2672.0     49.34         3339.0
# 3 2005-02-07 03:00:00     6.97         165    3989.0   -117.99         1103.0
# 4 2005-02-07 04:00:00     3.47        1406       NaN       NaN            NaN
#
#    NOx(GT)  PT08.S3(NOx) NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)        T      RH  \
# 0    392.0         739.0     151        2508.0       2022.0    38.67   72.55
# 1    703.0         217.0     152        -226.0       1979.0   -67.64   60.83
# 2    230.0        3738.0     114        4780.0        755.0  4603.73   86.45
# 3   1920.0         402.0     -50        3850.0        -30.0    13.68  996.20
# 4      NaN           NaN      53           NaN          NaN      NaN     NaN
#
#         AH
# 0     2.22
# ...

# %% [markdown]
# ## III) Correction of all datatypes

# %%
func.df_correct_dtypes(new_df)
# Out:
#                  Date   CO(GT)  PT08.S1(CO)  NMHC(GT)    C6H6(GT)  \
# 0 2005-02-07 00:00:00     0.15         1066       870       25.87
# 1 2005-02-07 01:00:00  -236.98         1993       -96       46.68
# 2 2005-02-07 02:00:00  2330.12          944      2672       49.34
# 3 2005-02-07 03:00:00     6.97          165      3989     -117.99
# 4 2005-02-07 04:00:00     3.47         1406  -1024000 -1024000.00
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           2040      392           739      151          2508         2022
# 1            343      703           217      152          -226         1979
# 2           3339      230          3738      114          4780          755
# 3           1103     1920           402      -50          3850          -30
# 4       -1024000 -1024000      -1024000       53      -1024000     -1024000
#
#             T          RH          AH
# 0       38.67       72.55        2.22
# ...

# %% [markdown]
# ## IV) Changing column names

# %%
func.df_change_columns(new_df)
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt     c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     0.15        1066      870       25.87          2040
# 1 2005-02-07 01:00:00  -236.98        1993      -96       46.68           343
# 2 2005-02-07 02:00:00  2330.12         944     2672       49.34          3339
# 3 2005-02-07 03:00:00     6.97         165     3989     -117.99          1103
# 4 2005-02-07 04:00:00     3.47        1406 -1024000 -1024000.00      -1024000
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3           t  \
# 0      392          739     151         2508        2022       38.67
# 1      703          217     152         -226        1979      -67.64
# 2      230         3738     114         4780         755     4603.73
# 3     1920          402     -50         3850         -30       13.68
# 4 -1024000     -1024000      53     -1024000    -1024000 -1024000.00
#
#            rh          ah
# 0       72.55        2.22
# 1       60.83     -154.26
# ...

# %% [markdown]
# # B) All in One

# %%
first_df = func.json_to_prepared_df("00_LiveData.json")
first_df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     0.15        1066      870    25.87          2040
# 1 2005-02-07 01:00:00  -236.98        1993      -96    46.68           343
# 2 2005-02-07 02:00:00  2330.12         944     2672    49.34          3339
# 3 2005-02-07 03:00:00     6.97         165     3989  -117.99          1103
#
#    nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3        t      rh  \
# 0     392          739     151         2508        2022    38.67   72.55
# 1     703          217     152         -226        1979   -67.64   60.83
# 2     230         3738     114         4780         755  4603.73   86.45
# 3    1920          402     -50         3850         -30    13.68  996.20
#
#         ah
# 0     2.22
# 1  -154.26
# 2  1215.30
# 3     1.98

# %%
last_df =func.json_to_prepared_df("01_LiveData_missing.json")
last_df
# Out:
#                  date  co_gt  pt08_s1_co  nmhc_gt    c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 04:00:00   3.47        1406 -1024000 -1024000.0      -1024000
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3          t  \
# 0 -1024000     -1024000      53     -1024000    -1024000 -1024000.0
#
#           rh         ah
# 0 -1024000.0 -1024000.0

# %%
all_df = func.json_to_prepared_df("02_LiveData_all.json")
all_df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt     c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     0.15        1066      870       25.87          2040
# 1 2005-02-07 01:00:00  -236.98        1993      -96       46.68           343
# 2 2005-02-07 02:00:00  2330.12         944     2672       49.34          3339
# 3 2005-02-07 03:00:00     6.97         165     3989     -117.99          1103
# 4 2005-02-07 04:00:00     3.47        1406 -1024000 -1024000.00      -1024000
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3           t  \
# 0      392          739     151         2508        2022       38.67
# 1      703          217     152         -226        1979      -67.64
# 2      230         3738     114         4780         755     4603.73
# 3     1920          402     -50         3850         -30       13.68
# 4 -1024000     -1024000      53     -1024000    -1024000 -1024000.00
#
#            rh          ah
# 0       72.55        2.22
# 1       60.83     -154.26
# ...

# %% [markdown]
# # Concat Dataframes

# %%
new_df = func.dfs_concat(first_df, last_df)
new_df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt     c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     0.15        1066      870       25.87          2040
# 1 2005-02-07 01:00:00  -236.98        1993      -96       46.68           343
# 2 2005-02-07 02:00:00  2330.12         944     2672       49.34          3339
# 3 2005-02-07 03:00:00     6.97         165     3989     -117.99          1103
# 4 2005-02-07 04:00:00     3.47        1406 -1024000 -1024000.00      -1024000
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3           t  \
# 0      392          739     151         2508        2022       38.67
# 1      703          217     152         -226        1979      -67.64
# 2      230         3738     114         4780         755     4603.73
# 3     1920          402     -50         3850         -30       13.68
# 4 -1024000     -1024000      53     -1024000    -1024000 -1024000.00
#
#            rh          ah
# 0       72.55        2.22
# 1       60.83     -154.26
# ...

# %%
old_df = pd.read_csv(org.path("01_AirQuality_processed.csv"), sep=';')

# %%
complete_df = func.dfs_concat(old_df, first_df, last_df)
complete_df
# Out:
#                      date    co_gt  pt08_s1_co    nmhc_gt     c6h6_gt  \
# 0     2004-03-10 18:00:00     2.60      1360.0      150.0       11.90
# 1     2004-03-10 19:00:00     2.00      1292.0      112.0        9.40
# 2     2004-03-10 20:00:00     2.20      1402.0       88.0        9.00
# 3     2004-03-10 21:00:00     2.20      1376.0       80.0        9.20
# 4     2004-03-10 22:00:00     1.60      1272.0       51.0        6.50
# ...                   ...      ...         ...        ...         ...
# 7998  2005-02-07 00:00:00     0.15      1066.0      870.0       25.87
# 7999  2005-02-07 01:00:00  -236.98      1993.0      -96.0       46.68
# 8000  2005-02-07 02:00:00  2330.12       944.0     2672.0       49.34
# 8001  2005-02-07 03:00:00     6.97       165.0     3989.0     -117.99
# 8002  2005-02-07 04:00:00     3.47      1406.0 -1024000.0 -1024000.00
#
#       pt08_s2_nmhc     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3  \
# ...

# %% [markdown]
# # Proof of Concept

# %%
path = org.path("00_RawFeatureList.csv")
fl_df = pd.read_csv(path, sep=';', decimal='.', index_col='names')
fl_df
# Out:
#                      mean       min        25%        50%        75%  \
# names
# co_gt            2.168604    0.1000     1.1000     1.8000     2.9000
# pt08_s1_co    1098.303412  647.0000   932.0000  1061.0000  1234.0000
# nmhc_gt        218.607666    7.0000    66.0000   145.0000   297.0000
# c6h6_gt         10.458205    0.1000     4.7000     8.6000    14.4000
# pt08_s2_nmhc   953.579453  383.0000   749.0000   925.0000  1130.0000
# nox_gt         232.360072    2.0000    89.0000   164.0000   303.7500
# pt08_s3_nox    848.762615  322.0000   672.0000   818.0000   984.0000
# no2_gt         106.251831    2.0000    73.0000   103.0000   132.0000
# pt08_s4_no2   1507.352834  657.0000  1305.0000  1508.0000  1707.0000
# pt08_s5_o3    1024.200026  253.0000   737.0000   962.0000  1272.0000
# t               19.476041    0.3000    13.1000    19.3000    25.4000
# rh              48.969244    9.2000    35.5000    49.4000    62.1000
# ...

# %%
all_df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt     c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     0.15        1066      870       25.87          2040
# 1 2005-02-07 01:00:00  -236.98        1993      -96       46.68           343
# 2 2005-02-07 02:00:00  2330.12         944     2672       49.34          3339
# 3 2005-02-07 03:00:00     6.97         165     3989     -117.99          1103
# 4 2005-02-07 04:00:00     3.47        1406 -1024000 -1024000.00      -1024000
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3           t  \
# 0      392          739     151         2508        2022       38.67
# 1      703          217     152         -226        1979      -67.64
# 2      230         3738     114         4780         755     4603.73
# 3     1920          402     -50         3850         -30       13.68
# 4 -1024000     -1024000      53     -1024000    -1024000 -1024000.00
#
#            rh          ah
# 0       72.55        2.22
# 1       60.83     -154.26
# ...

# %%
test_df = func.filter_plausible(all_df, fl_df)
test_df
# Out:
#                  date  co_gt  pt08_s1_co  nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00   0.15      1066.0    870.0    25.87        2040.0
# 1 2005-02-07 01:00:00    NaN      1993.0      NaN    46.68           NaN
# 2 2005-02-07 02:00:00    NaN       944.0      NaN    49.34           NaN
# 3 2005-02-07 03:00:00   6.97         NaN      NaN      NaN        1103.0
# 4 2005-02-07 04:00:00   3.47      1406.0      NaN      NaN           NaN
#
#    nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3      t     rh    ah
# 0   392.0        739.0   151.0       2508.0      2022.0  38.67  72.55  2.22
# 1   703.0          NaN   152.0          NaN      1979.0    NaN  60.83   NaN
# 2   230.0          NaN   114.0          NaN       755.0    NaN  86.45   NaN
# 3     NaN        402.0     NaN          NaN         NaN  13.68    NaN  1.98
# 4     NaN          NaN    53.0          NaN         NaN    NaN    NaN   NaN
