# %%
# imports
import pandas as pd
from pandas_profiling import ProfileReport
import orga_functions as org

# %%
# read in the dataframes
df = pd.read_csv(org.path("01_AirQuality_processed.csv"), sep=';')
feature_df = pd.read_csv(org.path("00_FeatureList_original.csv"), sep =";")

# %%
profile = ProfileReport(df, title = "AirQuality Report")

# %%
df
# Out:
#                      date  co_gt  pt08_s1_co  nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# 0     2004-03-10 18:00:00    2.6      1360.0    150.0     11.9        1046.0
# 1     2004-03-10 19:00:00    2.0      1292.0    112.0      9.4         955.0
# 2     2004-03-10 20:00:00    2.2      1402.0     88.0      9.0         939.0
# 3     2004-03-10 21:00:00    2.2      1376.0     80.0      9.2         948.0
# 4     2004-03-10 22:00:00    1.6      1272.0     51.0      6.5         836.0
# ...                   ...    ...         ...      ...      ...           ...
# 7993  2005-02-06 19:00:00    1.6       985.0      NaN      4.5         736.0
# 7994  2005-02-06 20:00:00    1.8      1002.0      NaN      5.3         780.0
# 7995  2005-02-06 21:00:00    1.4       938.0      NaN      3.7         692.0
# 7996  2005-02-06 22:00:00    1.1       896.0      NaN      2.6         627.0
# 7997  2005-02-06 23:00:00    1.0       907.0      NaN      2.4         614.0
#
# ...

# %%
feature_df
# Out:
#            names         mean       min        25%        50%        75%  \
# 0          co_gt     2.168604    0.1000     1.1000     1.8000     2.9000
# 1     pt08_s1_co  1098.303412  647.0000   932.0000  1061.0000  1234.0000
# 2        nmhc_gt   218.607666    7.0000    66.0000   145.0000   297.0000
# 3        c6h6_gt    10.458205    0.1000     4.7000     8.6000    14.4000
# 4   pt08_s2_nmhc   953.579453  383.0000   749.0000   925.0000  1130.0000
# 5         nox_gt   232.360072    2.0000    89.0000   164.0000   303.7500
# 6    pt08_s3_nox   848.762615  322.0000   672.0000   818.0000   984.0000
# 7         no2_gt   106.251831    2.0000    73.0000   103.0000   132.0000
# 8    pt08_s4_no2  1507.352834  657.0000  1305.0000  1508.0000  1707.0000
# 9     pt08_s5_o3  1024.200026  253.0000   737.0000   962.0000  1272.0000
# 10             t    19.476041    0.3000    13.1000    19.3000    25.4000
# 11            rh    48.969244    9.2000    35.5000    49.4000    62.1000
# ...

# %%
# name with discription
name = feature_df["names"].values
discription= feature_df["erläuterung"].values
name_dict = dict(zip(name, discription))

# %%
profile.config.variables.descriptions = name_dict

# %%
# save the report as HTML
file_path = org.path("AirQuality_report.html")
profile.to_file(output_file = file_path)
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
