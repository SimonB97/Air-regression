# %% [markdown]
# # Purpose of the Notebook:

# %% [markdown]
# In this Notebook a new CSV file for continouos updates is created.

# %% [markdown]
# # Create a CSV file for continouos updates

# %%
# imports
import pandas as pd
import orga_functions as org
import X4_ReadJSON as readj

# %%
df = pd.read_csv(org.path("02_AirQuality_processed.csv"), sep=';', index_col='date')

# %%
df
# Out:
#                      co_gt  pt08_s1_co     nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# date
# 2004-03-10 18:00:00    2.6      1360.0  150.000000     11.9   1046.000000
# 2004-03-10 19:00:00    2.0      1292.0  112.000000      9.4    955.000000
# 2004-03-10 20:00:00    2.2      1402.0   88.000000      9.0    939.000000
# 2004-03-10 21:00:00    2.2      1376.0   80.000000      9.2    948.000000
# 2004-03-10 22:00:00    1.6      1272.0   51.000000      6.5    836.000000
# ...                    ...         ...         ...      ...           ...
# 2005-02-06 19:00:00    1.6       985.0  218.607666      4.5    953.579453
# 2005-02-06 20:00:00    1.8      1002.0  218.607666      5.3    780.000000
# 2005-02-06 21:00:00    1.4       938.0  218.607666      3.7    953.579453
# 2005-02-06 22:00:00    1.1       896.0  218.607666      2.6    953.579453
# 2005-02-06 23:00:00    1.0       907.0  218.607666      2.4    953.579453
#
# ...

# %%
# save 
new_path = org.path("03_AirQuality_continuous.csv")
df.to_csv(new_path, sep=';', index = True)
