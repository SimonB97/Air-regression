# %% [markdown]
# # Purpose of the Notebook:

# %% [markdown]
# > In this notebook, a regressor is used to make a prediction from the previously simulated data.
# > The data is saved automatically, thus the regressor could be trained again and the mean values could be calculated again

# %% [markdown]
# # Unit Test with saving the new entries

# %% [markdown]
# ### imports

# %%
#imports
import pandas as pd
import pickle
import json
import orga_functions as org
import X5_ReadJSON_continuous as readjc

# %%
# import model
with open(org.path("LinearRegression_ah_regressor.pkl"), 'rb') as f:
    linr_clf = pickle.load(f)

# %%
# entire data set
df_continuous = pd.read_csv(org.path("03_AirQuality_continuous.csv"), sep=';')
df_continuous
# Out:
#                      date  co_gt  pt08_s1_co     nmhc_gt  c6h6_gt  \
# 0     2004-03-10 18:00:00    2.6      1360.0  150.000000     11.9
# 1     2004-03-10 19:00:00    2.0      1292.0  112.000000      9.4
# 2     2004-03-10 20:00:00    2.2      1402.0   88.000000      9.0
# 3     2004-03-10 21:00:00    2.2      1376.0   80.000000      9.2
# 4     2004-03-10 22:00:00    1.6      1272.0   51.000000      6.5
# ...                   ...    ...         ...         ...      ...
# 7993  2005-02-06 19:00:00    1.6       985.0  218.607666      4.5
# 7994  2005-02-06 20:00:00    1.8      1002.0  218.607666      5.3
# 7995  2005-02-06 21:00:00    1.4       938.0  218.607666      3.7
# 7996  2005-02-06 22:00:00    1.1       896.0  218.607666      2.6
# 7997  2005-02-06 23:00:00    1.0       907.0  218.607666      2.4
#
#       pt08_s2_nmhc  nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3  \
# 0      1046.000000   166.0       1056.0   113.0       1692.0      1268.0
# ...

# %% [markdown]
# ## Test 1

# %% [markdown]
# prepared DataFrame from JSON file

# %%
json_df = readjc.json_to_prepared_df("01_LiveData.json")
json_df
# Out:
#         date  co_gt pt08_s1_co nmhc_gt  c6h6_gt pt08_s2_nmhc nox_gt  \
# 0 2005-02-07    3.3       1042     377    16.59         1436    187
#
#   pt08_s3_nox no2_gt pt08_s4_no2 pt08_s5_o3    t     rh    ah
# 0        1232    184        1290        525  1.2  87.77  0.47

# %% [markdown]
# prediction

# %%
# prediction + saving the entry
readjc.pred_json_df("01_LiveData.json", linr_clf )
# Out:
#                      predicted_ah
# future_datetime
# 2005-02-07 06:00:00      0.475788

# %% [markdown]
# check if the entry is saved

# %%
df_continuous = pd.read_csv(org.path("03_AirQuality_continuous.csv"), sep=';')
df_continuous.tail(1)
# Out:
#                      date  co_gt  pt08_s1_co  nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# 7998  2005-02-07 00:00:00    3.3      1042.0    377.0    16.59        1436.0
#
#       nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3    t     rh    ah
# 7998   187.0       1232.0   184.0       1290.0       525.0  1.2  87.77  0.47

# %% [markdown]
# ## Test 2

# %%
readjc.pred_json_df("02_LiveData.json", linr_clf )
# Out:
#                      predicted_ah
# future_datetime
# 2005-02-07 07:00:00      0.484552

# %% [markdown]
# ## Test 3

# %%
readjc.pred_json_df("03_LiveData.json", linr_clf )
# Out:
#                      predicted_ah
# future_datetime
# 2005-02-07 08:00:00      0.464831

# %% [markdown]
# ## check the whole data set

# %%
df_continuous = pd.read_csv(org.path("03_AirQuality_continuous.csv"), sep=';', index_col = "date")
df_continuous
# Out:
#                         co_gt  pt08_s1_co     nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# date
# 2004-03-10 18:00:00  2.600000      1360.0  150.000000    11.90   1046.000000
# 2004-03-10 19:00:00  2.000000      1292.0  112.000000     9.40    955.000000
# 2004-03-10 20:00:00  2.200000      1402.0   88.000000     9.00    939.000000
# 2004-03-10 21:00:00  2.200000      1376.0   80.000000     9.20    948.000000
# 2004-03-10 22:00:00  1.600000      1272.0   51.000000     6.50    836.000000
# ...                       ...         ...         ...      ...           ...
# 2005-02-06 22:00:00  1.100000       896.0  218.607666     2.60    953.579453
# 2005-02-06 23:00:00  1.000000       907.0  218.607666     2.40    953.579453
# 2005-02-07 00:00:00  3.300000      1042.0  377.000000    16.59   1436.000000
# 2005-02-07 01:00:00  2.168604      1264.0  218.607666    25.87    953.579453
# 2005-02-07 02:00:00  2.168604      1240.0  218.607666    19.59    953.579453
#
# ...
