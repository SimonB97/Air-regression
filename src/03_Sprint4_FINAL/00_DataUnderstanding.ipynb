# %% [markdown]
# # Purpose of the Notebook:
# The purpose of this notebook is to view and become familiar with the data set. What are the columns, how many columns are there and what are the data types of each column.

# %%
# imports
import pandas as pd

# %%
# read in the dataframe
url = 'https://raw.githubusercontent.com/joa24jm/21-12-13_air-qual/master/data/01_raw/AirQualityUCI.csv'
df = pd.read_csv(url, sep=';', decimal=',')

# %% [markdown]
# # Erste Untersuchung

# %%
# first output
df.head(12)
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0   10/03/2004  18.00.00     2.6         1360       150      11.9
# 1   10/03/2004  19.00.00     2.0         1292       112       9.4
# 2   10/03/2004  20.00.00     2.2         1402        88       9.0
# 3   10/03/2004  21.00.00     2.2         1376        80       9.2
# 4   10/03/2004  22.00.00     1.6         1272        51       6.5
# 5   10/03/2004  23.00.00     1.2         1197        38       4.7
# 6   11/03/2004  00.00.00     1.2         1185        31       3.6
# 7   11/03/2004  01.00.00     1.0         1136        31       3.3
# 8   11/03/2004  02.00.00     0.9         1094        24       2.3
# 9   11/03/2004  03.00.00     0.6         1010        19       1.7
# 10  11/03/2004  04.00.00  -200.0         1011        14       1.3
# 11  11/03/2004  05.00.00     0.7         1066         8       1.1
#
#     PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# ...

# %%
# number of rows and columns
df.shape
# Out:
# (7998, 17)

# %% [markdown]
# ### Einzelne Zeilen und Spalten

# %%
#first row
df.head(1)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6         1360       150      11.9
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN

# %%
#last row
df.tail(1)
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 7997  06/02/2005  23.00.00     1.0          907      -200       2.4
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 7997            614      150          1052      120           782
#
#       PT08.S5(O3)    T    RH      AH  Unnamed: 15  Unnamed: 16
# 7997          627  5.1  37.9  0.3358          NaN          NaN

# %%
#first and last column
df.iloc[:, [0, -1]]
# Out:
#             Date  Unnamed: 16
# 0     10/03/2004          NaN
# 1     10/03/2004          NaN
# 2     10/03/2004          NaN
# 3     10/03/2004          NaN
# 4     10/03/2004          NaN
# ...          ...          ...
# 7993  06/02/2005          NaN
# 7994  06/02/2005          NaN
# 7995  06/02/2005          NaN
# 7996  06/02/2005          NaN
# 7997  06/02/2005          NaN
#
# [7998 rows x 2 columns]

# %% [markdown]
# ### Informationen

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  7998.000000  7998.000000  7998.000000  7998.000000    7998.000000
# mean    -39.626619  1051.390473  -152.138785     2.853501     911.895974
# std      81.903331   324.558998   150.096708    39.977717     340.000627
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.500000   917.000000  -200.000000     4.300000     727.000000
# 50%       1.500000  1051.500000  -200.000000     8.300000     911.000000
# 75%       2.600000  1225.000000  -200.000000    14.200000    1122.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  7998.000000   7998.000000  7998.000000   7998.000000  7998.000000
# mean    149.096524    810.866592    45.156164   1445.659290   979.964741
# std     260.628377    321.385807   129.330765    455.347712   449.200147
# ...

# %%
# number of rows and columns
df.shape
# Out:
# (7998, 17)

# %%
# checking datatypes of all columns
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)        int64
# NMHC(GT)           int64
# C6H6(GT)         float64
# PT08.S2(NMHC)      int64
# NOx(GT)            int64
# PT08.S3(NOx)       int64
# NO2(GT)            int64
# PT08.S4(NO2)       int64
# PT08.S5(O3)        int64
# T                float64
# RH               float64
# AH               float64
# Unnamed: 15      float64
# Unnamed: 16      float64
# dtype: object

# %% [markdown]
# > While familiarizing ourselves with the data set, we quickly noticed some superfluous and incorrect formatting. The features "Unnamed: 15" and "Unnamed: 16" are superfluous, since they contain absolutely no value and they have no proper name. We have recognized a wrong formatting in the features "Date" and "Time", because they are not formatted as data type "date" or "time". Furthermore, we recognized that the value -200 occurs relatively often and must therefore be examined more closely.

# %% [markdown]
# # Lokale Kopie der Daten

# %%
df.to_csv('../../data/csv/AirQuality/00_AirQuality_original.csv', sep=';', index = False)
