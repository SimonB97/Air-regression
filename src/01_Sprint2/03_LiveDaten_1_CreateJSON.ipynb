# %%
import json
import pandas as pd
import numpy as np
import orga_functions as org
import functions as func

# %%
# read in the dataframe
path = org.path("00_FeatureList_original.csv")
feature_df = pd.read_csv(path, sep =";")

# %% [markdown]
# ## FeatureList DataPreparation

# %%
feature_df
# Out:
#            names         mean       min        25%        50%        75%  \
# 0          co_gt     2.168604    0.1000     1.1000     1.8000     2.9000
# 1     pt08_s1_co  1098.303412  647.0000   932.0000  1061.0000  1234.0000
# 2        nmhc_gt   218.607666    7.0000    66.0000   145.0000   297.0000
# 3        c6h6_gt    10.458205    0.1000     4.7000     8.6000    14.4000
# 4   pt08_s2_nmhc   953.579453  383.0000   749.0000   925.0000  1130.0000
# 5         nox_gt   232.360072    2.0000    89.0000   164.0000   303.7500
# 6    pt08_s3_nox   848.762615  322.0000   672.0000   818.0000   984.0000
# 7         no2_gt   106.251831    2.0000    73.0000   103.0000   132.0000
# 8    pt08_s4_no2  1507.352834  657.0000  1305.0000  1508.0000  1707.0000
# 9     pt08_s5_o3  1024.200026  253.0000   737.0000   962.0000  1272.0000
# 10             t    19.476041    0.3000    13.1000    19.3000    25.4000
# 11            rh    48.969244    9.2000    35.5000    49.4000    62.1000
# 12            ah     1.082099    0.1988     0.8167     1.0468     1.3713
# 13         month     6.928525    1.0000     4.0000     7.0000    10.0000
# 14          hour    11.488520    0.0000     6.0000    11.0000    17.0000
#
#          max                                        erläuterung
# 0     11.900             stuendlich gemittelte CO-Konzentration
# 1   2040.000  stuendlich gemittelte Sensorreaktion (nominell...
# 2   1189.000  stuendlich gemittelte Gesamtkonzentration an n...
# 3     63.700          stuendlich gemittelte Benzolkonzentration
# 4   2214.000  stuendlich gemittelte Sensorreaktion (nominell...
# 5   1479.000      Echte stuendlich gemittelte NOx-Konzentration
# 6   2683.000  stuendlich gemitteltes Sensoransprechverhalten...
# 7    333.000            stuendlich gemittelte NO2-Konzentration
# 8   2775.000  stuendlich gemittelte Sensorreaktion (nominell...
# 9   2523.000  stuendlich gemitteltes Sensoransprechverhalten...
# 10    44.600                                         Temperatur
# 11    88.700                          Relative Luftfeuchtigkeit
# 12     2.231                          Absolute Luftfeuchtigkeit
# 13    12.000                               Monate der Erfassung
# 14    23.000                              Stunden der Erfassung

# %% [markdown]
# #### Original Names

# %%
# Original Dataframe
original_names = pd.read_csv(org.path("00_AirQuality_original.csv"), sep=';', nrows=1).columns.tolist()
del original_names[15:]

# %%
# Replace names by original/raw names
def og_name(name):
    for og in original_names:
        if func.change_column(og) == name:
            return og
    return name

# %%
feature_df.names = [og_name(x) for x in feature_df.names]

# %%
feature_df
# Out:
#             names         mean       min        25%        50%        75%  \
# 0          CO(GT)     2.168604    0.1000     1.1000     1.8000     2.9000
# 1     PT08.S1(CO)  1098.303412  647.0000   932.0000  1061.0000  1234.0000
# 2        NMHC(GT)   218.607666    7.0000    66.0000   145.0000   297.0000
# 3        C6H6(GT)    10.458205    0.1000     4.7000     8.6000    14.4000
# 4   PT08.S2(NMHC)   953.579453  383.0000   749.0000   925.0000  1130.0000
# 5         NOx(GT)   232.360072    2.0000    89.0000   164.0000   303.7500
# 6    PT08.S3(NOx)   848.762615  322.0000   672.0000   818.0000   984.0000
# 7         NO2(GT)   106.251831    2.0000    73.0000   103.0000   132.0000
# 8    PT08.S4(NO2)  1507.352834  657.0000  1305.0000  1508.0000  1707.0000
# 9     PT08.S5(O3)  1024.200026  253.0000   737.0000   962.0000  1272.0000
# 10              T    19.476041    0.3000    13.1000    19.3000    25.4000
# 11             RH    48.969244    9.2000    35.5000    49.4000    62.1000
# 12             AH     1.082099    0.1988     0.8167     1.0468     1.3713
# 13          month     6.928525    1.0000     4.0000     7.0000    10.0000
# 14           hour    11.488520    0.0000     6.0000    11.0000    17.0000
#
#          max                                        erläuterung
# 0     11.900             stuendlich gemittelte CO-Konzentration
# 1   2040.000  stuendlich gemittelte Sensorreaktion (nominell...
# 2   1189.000  stuendlich gemittelte Gesamtkonzentration an n...
# 3     63.700          stuendlich gemittelte Benzolkonzentration
# 4   2214.000  stuendlich gemittelte Sensorreaktion (nominell...
# 5   1479.000      Echte stuendlich gemittelte NOx-Konzentration
# 6   2683.000  stuendlich gemitteltes Sensoransprechverhalten...
# 7    333.000            stuendlich gemittelte NO2-Konzentration
# 8   2775.000  stuendlich gemittelte Sensorreaktion (nominell...
# 9   2523.000  stuendlich gemitteltes Sensoransprechverhalten...
# 10    44.600                                         Temperatur
# 11    88.700                          Relative Luftfeuchtigkeit
# 12     2.231                          Absolute Luftfeuchtigkeit
# 13    12.000                               Monate der Erfassung
# 14    23.000                              Stunden der Erfassung

# %% [markdown]
# #### Names as Index

# %%
feature_df.set_index('names', inplace = True)

# %%
feature_df.drop(index = ["month", "hour"], inplace = True)

# %%
feature_df[["min", "max"]]
# Out:
#                     min       max
# names
# CO(GT)           0.1000    11.900
# PT08.S1(CO)    647.0000  2040.000
# NMHC(GT)         7.0000  1189.000
# C6H6(GT)         0.1000    63.700
# PT08.S2(NMHC)  383.0000  2214.000
# NOx(GT)          2.0000  1479.000
# PT08.S3(NOx)   322.0000  2683.000
# NO2(GT)          2.0000   333.000
# PT08.S4(NO2)   657.0000  2775.000
# PT08.S5(O3)    253.0000  2523.000
# T                0.3000    44.600
# RH               9.2000    88.700
# AH               0.1988     2.231

# %% [markdown]
# # Create new entries

# %% [markdown]
# ### Functions

# %%
def get_min(name):
    return feature_df.loc[name]["min"]
                         
def get_max(name):
    return feature_df.loc[name]["max"]

# %%
int_columns = func.og_int_column_list()

# %%
def get_correct(name):
    if name in int_columns:
        value = np.random.randint(get_min(name), get_max(name))
        return value
    else:
        value = np.random.uniform(get_min(name), get_max(name))
        return round(value, 2)

# %%
def get_too_small(name):
    if name in int_columns:
        value = np.random.randint(-250, get_min(name)-1)
        return value
    else:
        value = np.random.uniform(-250, get_min(name)-1)
        return round(value, 2)

# %%
def get_too_big(name):
    if name in int_columns:
        value = np.random.randint(get_max(name)+1, 5000)
        return value
    else:
        value = np.random.uniform(get_max(name)+1, 5000)
        return round(value, 2)

# %% [markdown]
# ## Entry with only correct values

# %%
corr_dict = {}
for i in feature_df.index.values:
    corr_dict[i] = get_correct(i)

# %%
corr_dict["Date"] = "07/02/2005"
corr_dict["Time"] = '00.00.00'

# %% [markdown]
# ## Entry with some too small values

# %%
change = 1
small_dict = {}
for i in feature_df.index.values:
    if change %2 == 0:
        small_dict[i] = get_correct(i)
    else:
        small_dict[i] = get_too_small(i)
    change+=1

# %%
small_dict["Date"] = "07/02/2005"
small_dict["Time"] = '01.00.00'

# %% [markdown]
# ## Entry some too big values

# %%
change = 1
big_dict = {}
for i in feature_df.index.values:
    if change % 2 == 0:
        big_dict[i] = get_correct(i)
    else:
        big_dict[i] = get_too_big(i)
    change+=1

# %%
big_dict["Date"] = "07/02/2005"
big_dict["Time"] = '02.00.00'

# %% [markdown]
# ## Entry with mix values

# %%
change = 1
mix_dict = {}
for i in feature_df.index.values:
    if change % 3 == 0:       #3,6,9,12
        mix_dict[i] = get_too_big(i)
    elif change % 2 == 0: #2,4,(6),8,10,(12)
        mix_dict[i] = get_too_small(i)
    else:                       #1,5,7,11,13
        mix_dict[i] = get_correct(i)
    change+=1

# %%
mix_dict["Date"] = "07/02/2005"
mix_dict["Time"] = '03.00.00'

# %% [markdown]
# ## Entry with missing  values

# %%
missing_dict = {}

# %%
feature_df
# Out:
#                       mean       min        25%        50%        75%  \
# names
# CO(GT)            2.168604    0.1000     1.1000     1.8000     2.9000
# PT08.S1(CO)    1098.303412  647.0000   932.0000  1061.0000  1234.0000
# NMHC(GT)        218.607666    7.0000    66.0000   145.0000   297.0000
# C6H6(GT)         10.458205    0.1000     4.7000     8.6000    14.4000
# PT08.S2(NMHC)   953.579453  383.0000   749.0000   925.0000  1130.0000
# NOx(GT)         232.360072    2.0000    89.0000   164.0000   303.7500
# PT08.S3(NOx)    848.762615  322.0000   672.0000   818.0000   984.0000
# NO2(GT)         106.251831    2.0000    73.0000   103.0000   132.0000
# PT08.S4(NO2)   1507.352834  657.0000  1305.0000  1508.0000  1707.0000
# PT08.S5(O3)    1024.200026  253.0000   737.0000   962.0000  1272.0000
# T                19.476041    0.3000    13.1000    19.3000    25.4000
# RH               48.969244    9.2000    35.5000    49.4000    62.1000
# AH                1.082099    0.1988     0.8167     1.0468     1.3713
#
#                     max                                        erläuterung
# names
# CO(GT)           11.900             stuendlich gemittelte CO-Konzentration
# PT08.S1(CO)    2040.000  stuendlich gemittelte Sensorreaktion (nominell...
# NMHC(GT)       1189.000  stuendlich gemittelte Gesamtkonzentration an n...
# C6H6(GT)         63.700          stuendlich gemittelte Benzolkonzentration
# PT08.S2(NMHC)  2214.000  stuendlich gemittelte Sensorreaktion (nominell...
# NOx(GT)        1479.000      Echte stuendlich gemittelte NOx-Konzentration
# PT08.S3(NOx)   2683.000  stuendlich gemitteltes Sensoransprechverhalten...
# NO2(GT)         333.000            stuendlich gemittelte NO2-Konzentration
# PT08.S4(NO2)   2775.000  stuendlich gemittelte Sensorreaktion (nominell...
# PT08.S5(O3)    2523.000  stuendlich gemitteltes Sensoransprechverhalten...
# T                44.600                                         Temperatur
# RH               88.700                          Relative Luftfeuchtigkeit
# AH                2.231                          Absolute Luftfeuchtigkeit

# %%
missing_dict["Date"] = "07/02/2005"
missing_dict["Time"] = '04.00.00'

# %%
missing_dict["CO(GT)"] = get_correct('CO(GT)')
missing_dict["PT08.S1(CO)"] = get_correct('PT08.S1(CO)')
missing_dict["NO2(GT)"] = get_correct('NO2(GT)')

# %%
missing_dict["NOx(GT)"] = np.nan

# %% [markdown]
# # Save  LiveData in JSON File

# %%
#function
def entry_list(*entries):
    list = []
    for e in entries:
        list.append(e)
    return list

# %%
#print(json.dumps(entries_v1, indent = 2))

# %% [markdown]
# ### Save without missing values

# %%
entries_v1 = entry_list(corr_dict, small_dict, big_dict, mix_dict)

# %%
# Save as JSON file
new_path = org.path("00_LiveData.json")

with open(new_path, 'w') as jf:
    json.dump(entries_v1, jf, indent = 2)

# %% [markdown]
# ### Save only the entry with missing values

# %%
# Save as JSON file
new_path = org.path("01_LiveData_missing.json")

with open(new_path, 'w') as jf:
    json.dump(entry_list(missing_dict), jf, indent = 2)

# %% [markdown]
# ### Save all

# %%
entries_all = entry_list(corr_dict, small_dict, big_dict, mix_dict, missing_dict)

# %%
# Save as JSON file
new_path = org.path("02_LiveData_all.json")

with open(new_path, 'w') as jf:
    json.dump(entries_all, jf, indent = 2)
