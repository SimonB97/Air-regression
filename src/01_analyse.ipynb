# %%
# imports
import pandas as pd

# %%
# read in the dataframe
url = 'https://raw.githubusercontent.com/joa24jm/21-12-13_air-qual/master/data/01_raw/AirQualityUCI.csv'
df = pd.read_csv(url, sep=';')

# %%
# describe the dataframe
df.describe()
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  7998.000000  7998.000000    7998.000000  7998.000000   7998.000000
# mean   1051.390473  -152.138785     911.895974   149.096524    810.866592
# std     324.558998   150.096708     340.000627   260.628377    321.385807
# min    -200.000000  -200.000000    -200.000000  -200.000000   -200.000000
# 25%     917.000000  -200.000000     727.000000    39.000000    652.000000
# 50%    1051.500000  -200.000000     911.000000   122.000000    807.000000
# 75%    1225.000000  -200.000000    1122.000000   259.750000    976.000000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  Unnamed: 15  Unnamed: 16
# count  7998.000000   7998.000000  7998.000000          0.0          0.0
# mean     45.156164   1445.659290   979.964741          NaN          NaN
# std     129.330765    455.347712   449.200147          NaN          NaN
# min    -200.000000   -200.000000  -200.000000          NaN          NaN
# 25%      44.000000   1275.250000   710.000000          NaN          NaN
# 50%      90.000000   1494.000000   942.000000          NaN          NaN
# 75%     125.000000   1698.000000  1253.750000          NaN          NaN
# max     333.000000   2775.000000  2523.000000          NaN          NaN

# %% [markdown]
# # This is a heading
# ## This is a subheading
# - this is a list element
# - this is another list element

# %% [markdown]
# ![image.png](attachment:image.png)
