# %%
import pandas as pd
import orga_functions as org
import functions as func

# %% [markdown]
# # Data Preparation

# %%
# read in the original dataframe
path = org.path("00_AirQuality_original.csv")
df = pd.read_csv(path, sep=';')

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6         1360       150      11.9
# 1     10/03/2004  19.00.00     2.0         1292       112       9.4
# 2     10/03/2004  20.00.00     2.2         1402        88       9.0
# 3     10/03/2004  21.00.00     2.2         1376        80       9.2
# 4     10/03/2004  22.00.00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 7993  06/02/2005  19.00.00     1.6          985      -200       4.5
# 7994  06/02/2005  20.00.00     1.8         1002      -200       5.3
# 7995  06/02/2005  21.00.00     1.4          938      -200       3.7
# 7996  06/02/2005  22.00.00     1.1          896      -200       2.6
# 7997  06/02/2005  23.00.00     1.0          907      -200       2.4
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
# drops unknown columns
#corrects datetime
#changes column names to small letters,
#filter plausible feature values and replaces them by NaN
df = func.data_preparation_df(df)

# %%
df
# Out:
#                     date  co_gt  pt08_s1_co  nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# 0    2004-03-10 18:00:00    2.6      1360.0      150     11.9        1046.0
# 1    2004-03-10 19:00:00    2.0      1292.0      112      9.4         955.0
# 2    2004-03-10 20:00:00    2.2      1402.0       88      9.0         939.0
# 3    2004-03-10 21:00:00    2.2      1376.0       80      9.2         948.0
# 4    2004-03-10 22:00:00    1.6      1272.0       51      6.5         836.0
# ...                  ...    ...         ...      ...      ...           ...
# 7993 2005-02-06 19:00:00    1.6       985.0     -200      4.5           NaN
# 7994 2005-02-06 20:00:00    1.8      1002.0     -200      5.3         780.0
# 7995 2005-02-06 21:00:00    1.4       938.0     -200      3.7           NaN
# 7996 2005-02-06 22:00:00    1.1       896.0     -200      2.6           NaN
# 7997 2005-02-06 23:00:00    1.0       907.0     -200      2.4           NaN
#
# ...

# %%
# check for null values
df["co_gt"].isnull().values.any()
# Out:
# True

# %% [markdown]
# ## missing value treatment

# %%
treated_df = func.df_replace_missing(df, feature_df_path = "02_PlausFeatureList.csv")

# %%
treated_df
# Out:
#                     date  co_gt  pt08_s1_co  c6h6_gt  pt08_s2_nmhc  nox_gt  \
# 0    2004-03-10 18:00:00    2.6      1360.0     11.9   1046.000000   166.0
# 1    2004-03-10 19:00:00    2.0      1292.0      9.4    955.000000   103.0
# 2    2004-03-10 20:00:00    2.2      1402.0      9.0    939.000000   131.0
# 3    2004-03-10 21:00:00    2.2      1376.0      9.2    948.000000   172.0
# 4    2004-03-10 22:00:00    1.6      1272.0      6.5    836.000000   131.0
# ...                  ...    ...         ...      ...           ...     ...
# 7993 2005-02-06 19:00:00    1.6       985.0      4.5    953.579453   227.0
# 7994 2005-02-06 20:00:00    1.8      1002.0      5.3    780.000000   252.0
# 7995 2005-02-06 21:00:00    1.4       938.0      3.7    953.579453   193.0
# 7996 2005-02-06 22:00:00    1.1       896.0      2.6    953.579453   158.0
# 7997 2005-02-06 23:00:00    1.0       907.0      2.4    953.579453   150.0
#
# ...

# %%
# check for null values
treated_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Speichern

# %%
# save dataset locally
new_path = org.path("02_AirQuality_processed.csv")
treated_df.to_csv(new_path, sep=';', index = False)
