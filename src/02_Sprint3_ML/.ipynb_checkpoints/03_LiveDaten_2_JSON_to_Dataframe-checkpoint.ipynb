# %%
import pandas as pd
import orga_functions as org
import functions as func
import json

# %% [markdown]
# # Import Dataframes from JSON File

# %%
df = func.json_to_prepared_df("02_LiveData.json")
df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt     c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     6.77        1752      947       55.14          1561
# 1 2005-02-07 01:00:00   -47.76        1017      -12       38.83           274
# 2 2005-02-07 02:00:00  2445.49         725     3326       40.24          2792
# 3 2005-02-07 03:00:00     4.56         571     3859     -161.39          1590
# 4 2005-02-07 04:00:00     7.39        1655 -1024000 -1024000.00      -1024000
# 5 2005-02-07 05:00:00     2.84        1697      995       31.80          2051
# 6 2005-02-07 06:00:00    10.38         716      418       58.16          1276
# 7 2005-02-07 07:00:00     2.68         810      864       59.45           850
# 8 2005-02-07 08:00:00    11.20        1570       75        7.46           957
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3           t  \
# 0      377         2304     329         1061        2152       31.25
# 1     1362          108      49          -67        1175     -138.46
# 2     1192         4482     237         3298         618     4721.35
# 3     4991          827     -90         3062          22       30.87
# 4 -1024000     -1024000     198     -1024000    -1024000 -1024000.00
# 5     1231         1558     109          745        1520       25.02
# 6     1062          846     296         1101        2337        7.01
# 7     1076          385     172         1738        1974       38.42
# 8      573         1752     173         1982        1053       43.29
#
#            rh          ah
# 0       24.68        0.84
# 1       54.88     -218.87
# 2       80.01      357.52
# 3     3018.32        0.24
# 4 -1024000.00 -1024000.00
# 5       84.49        0.65
# 6       27.09        0.33
# 7       46.46        1.94
# 8       53.31        1.08

# %% [markdown]
# # Concat Dataframes

# %%
old_df = pd.read_csv(org.path("01_AirQuality_processed.csv"), sep=';')

# %%
concat_df = func.dfs_concat(old_df, df)
concat_df
# Out:
#                      date  co_gt  pt08_s1_co    nmhc_gt     c6h6_gt  \
# 0     2004-03-10 18:00:00   2.60      1360.0      150.0       11.90
# 1     2004-03-10 19:00:00   2.00      1292.0      112.0        9.40
# 2     2004-03-10 20:00:00   2.20      1402.0       88.0        9.00
# 3     2004-03-10 21:00:00   2.20      1376.0       80.0        9.20
# 4     2004-03-10 22:00:00   1.60      1272.0       51.0        6.50
# ...                   ...    ...         ...        ...         ...
# 8002  2005-02-07 04:00:00   7.39      1655.0 -1024000.0 -1024000.00
# 8003  2005-02-07 05:00:00   2.84      1697.0      995.0       31.80
# 8004  2005-02-07 06:00:00  10.38       716.0      418.0       58.16
# 8005  2005-02-07 07:00:00   2.68       810.0      864.0       59.45
# 8006  2005-02-07 08:00:00  11.20      1570.0       75.0        7.46
#
#       pt08_s2_nmhc     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3  \
# 0           1046.0      166.0       1056.0   113.0       1692.0      1268.0
# 1            955.0      103.0       1174.0    92.0       1559.0       972.0
# 2            939.0      131.0       1140.0   114.0       1555.0      1074.0
# 3            948.0      172.0       1092.0   122.0       1584.0      1203.0
# 4            836.0      131.0       1205.0   116.0       1490.0      1110.0
# ...            ...        ...          ...     ...          ...         ...
# 8002    -1024000.0 -1024000.0   -1024000.0   198.0   -1024000.0  -1024000.0
# 8003        2051.0     1231.0       1558.0   109.0        745.0      1520.0
# 8004        1276.0     1062.0        846.0   296.0       1101.0      2337.0
# 8005         850.0     1076.0        385.0   172.0       1738.0      1974.0
# 8006         957.0      573.0       1752.0   173.0       1982.0      1053.0
#
#                t          rh            ah
# 0          13.60       48.90  7.578000e-01
# 1          13.30       47.70  7.255000e-01
# 2          11.90       54.00  7.502000e-01
# 3          11.00       60.00  7.867000e-01
# 4          11.20       59.60  7.888000e-01
# ...          ...         ...           ...
# 8002 -1024000.00 -1024000.00 -1.024000e+06
# 8003       25.02       84.49  6.500000e-01
# 8004        7.01       27.09  3.300000e-01
# 8005       38.42       46.46  1.940000e+00
# 8006       43.29       53.31  1.080000e+00
#
# [8007 rows x 14 columns]

# %% [markdown]
# # JSON to DataFrame without missing values

# %%
# read in the feature dataframe
path = org.path("02_PlausFeatureList.csv")
feature_df = pd.read_csv(path, sep =";", index_col='names')

# %%
json_df = func.json_to_correct_df("02_LiveData.json", feature_df)

# %%
json_df
# Out:
#                  date     co_gt   pt08_s1_co    c6h6_gt  pt08_s2_nmhc  nox_gt  \
# 0 2005-02-07 00:00:00  2.168604  1098.303412  10.458205   1561.000000   377.0
# 1 2005-02-07 01:00:00  2.168604  1017.000000  10.458205    953.579453   377.0
# 2 2005-02-07 02:00:00  2.168604   725.000000  10.458205    953.579453   377.0
# 3 2005-02-07 03:00:00  4.560000  1098.303412  10.458205   1590.000000   377.0
# 4 2005-02-07 04:00:00  2.168604  1655.000000  10.458205    953.579453   377.0
# 5 2005-02-07 05:00:00  2.840000  1098.303412  10.458205    953.579453   377.0
# 6 2005-02-07 06:00:00  2.168604   716.000000  10.458205   1276.000000   377.0
# 7 2005-02-07 07:00:00  2.680000   810.000000  10.458205    850.000000   377.0
# 8 2005-02-07 08:00:00  2.168604  1570.000000   7.460000    957.000000   573.0
#
#    pt08_s3_nox      no2_gt  pt08_s4_no2  pt08_s5_o3      t     rh    ah
# 0   848.762615  106.251831       1061.0         NaN  31.25  24.68  0.84
# 1   848.762615   49.000000       1061.0      1175.0  31.25  54.88  0.84
# 2   848.762615  106.251831       1061.0       618.0  31.25  80.01  0.84
# 3   827.000000  106.251831       1061.0       618.0  30.87  80.01  0.24
# 4   848.762615  198.000000       1061.0       618.0  30.87  80.01  0.24
# 5   848.762615  109.000000        745.0      1520.0  25.02  84.49  0.65
# 6   846.000000  106.251831       1101.0      1520.0   7.01  27.09  0.33
# 7   385.000000  172.000000       1738.0      1974.0  38.42  46.46  1.94
# 8   848.762615  173.000000       1982.0      1053.0  43.29  53.31  1.08
