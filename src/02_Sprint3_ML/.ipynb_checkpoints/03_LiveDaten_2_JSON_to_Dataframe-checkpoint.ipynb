# %%
import pandas as pd
import orga_functions as org
import functions as func
import json

# %% [markdown]
# # Import Dataframes from JSON File

# %%
first_df = func.json_to_prepared_df("00_LiveData.json")
first_df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt  c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     4.73         910        7    23.54          1797
# 1 2005-02-07 01:00:00  -106.89        1151     -224    31.32          -116
# 2 2005-02-07 02:00:00  3831.32        1337     3235    11.20          3239
# 3 2005-02-07 03:00:00     2.90         547     1999  -249.49           674
#
#    nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3        t       rh  \
# 0     802          904     290         1135        1520    36.14    18.10
# 1     157          300     104          -58        1830  -224.95    80.81
# 2     257         2770     109         4306         622  3303.59    72.31
# 3    4803         1938    -217         3837        -158    16.69  2312.29
#
#         ah
# 0     1.81
# 1   -66.70
# 2  3609.47
# 3     0.32

# %%
last_df =func.json_to_prepared_df("01_LiveData_missing.json")
last_df
# Out:
#                  date  co_gt  pt08_s1_co  nmhc_gt    c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 04:00:00  10.37         729 -1024000 -1024000.0      -1024000
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3          t  \
# 0 -1024000     -1024000     155     -1024000    -1024000 -1024000.0
#
#           rh         ah
# 0 -1024000.0 -1024000.0

# %% [markdown]
# # Concat Dataframes

# %%
new_df = func.dfs_concat(first_df, last_df)
new_df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt     c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     4.73         910        7       23.54          1797
# 1 2005-02-07 01:00:00  -106.89        1151     -224       31.32          -116
# 2 2005-02-07 02:00:00  3831.32        1337     3235       11.20          3239
# 3 2005-02-07 03:00:00     2.90         547     1999     -249.49           674
# 4 2005-02-07 04:00:00    10.37         729 -1024000 -1024000.00      -1024000
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3           t  \
# 0      802          904     290         1135        1520       36.14
# 1      157          300     104          -58        1830     -224.95
# 2      257         2770     109         4306         622     3303.59
# 3     4803         1938    -217         3837        -158       16.69
# 4 -1024000     -1024000     155     -1024000    -1024000 -1024000.00
#
#            rh          ah
# 0       18.10        1.81
# 1       80.81      -66.70
# ...

# %%
old_df = pd.read_csv(org.path("01_AirQuality_processed.csv"), sep=';')

# %%
complete_df = func.dfs_concat(old_df, first_df, last_df)
complete_df
# Out:
#                      date    co_gt  pt08_s1_co    nmhc_gt     c6h6_gt  \
# 0     2004-03-10 18:00:00     2.60      1360.0      150.0       11.90
# 1     2004-03-10 19:00:00     2.00      1292.0      112.0        9.40
# 2     2004-03-10 20:00:00     2.20      1402.0       88.0        9.00
# 3     2004-03-10 21:00:00     2.20      1376.0       80.0        9.20
# 4     2004-03-10 22:00:00     1.60      1272.0       51.0        6.50
# ...                   ...      ...         ...        ...         ...
# 7998  2005-02-07 00:00:00     4.73       910.0        7.0       23.54
# 7999  2005-02-07 01:00:00  -106.89      1151.0     -224.0       31.32
# 8000  2005-02-07 02:00:00  3831.32      1337.0     3235.0       11.20
# 8001  2005-02-07 03:00:00     2.90       547.0     1999.0     -249.49
# 8002  2005-02-07 04:00:00    10.37       729.0 -1024000.0 -1024000.00
#
#       pt08_s2_nmhc     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3  \
# ...
