# %%
import pandas as pd
import orga_functions as org
import functions as func
import json

# %% [markdown]
# # Import Dataframes from JSON File

# %%
df = func.json_to_prepared_df("02_LiveData.json")
df
# Out:
#                  date    co_gt  pt08_s1_co  nmhc_gt     c6h6_gt  pt08_s2_nmhc  \
# 0 2005-02-07 00:00:00     3.53        1107      466       63.68          2038
# 1 2005-02-07 01:00:00   -76.52        1557      -74       24.77          -204
# 2 2005-02-07 02:00:00  2482.49        1781     2709        9.06          2777
# 3 2005-02-07 03:00:00     6.00         207     1239     -165.46          1888
# 4 2005-02-07 04:00:00    11.19         770 -1024000 -1024000.00      -1024000
# 5 2005-02-07 05:00:00     4.47        1003      592       48.93          1444
# 6 2005-02-07 06:00:00     2.72        1407     1112       34.43           400
# 7 2005-02-07 07:00:00    11.77         871      852       37.11           699
# 8 2005-02-07 08:00:00     3.62         662      717       52.97          1693
#
#     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3           t  \
# 0      550         2437      40         1878        1977       18.89
# ...

# %% [markdown]
# # Concat Dataframes

# %%
old_df = pd.read_csv(org.path("01_AirQuality_processed.csv"), sep=';')

# %%
concat_df = func.dfs_concat(old_df, df)
concat_df
# Out:
#                      date  co_gt  pt08_s1_co    nmhc_gt     c6h6_gt  \
# 0     2004-03-10 18:00:00   2.60      1360.0      150.0       11.90
# 1     2004-03-10 19:00:00   2.00      1292.0      112.0        9.40
# 2     2004-03-10 20:00:00   2.20      1402.0       88.0        9.00
# 3     2004-03-10 21:00:00   2.20      1376.0       80.0        9.20
# 4     2004-03-10 22:00:00   1.60      1272.0       51.0        6.50
# ...                   ...    ...         ...        ...         ...
# 8002  2005-02-07 04:00:00  11.19       770.0 -1024000.0 -1024000.00
# 8003  2005-02-07 05:00:00   4.47      1003.0      592.0       48.93
# 8004  2005-02-07 06:00:00   2.72      1407.0     1112.0       34.43
# 8005  2005-02-07 07:00:00  11.77       871.0      852.0       37.11
# 8006  2005-02-07 08:00:00   3.62       662.0      717.0       52.97
#
#       pt08_s2_nmhc     nox_gt  pt08_s3_nox  no2_gt  pt08_s4_no2  pt08_s5_o3  \
# ...

# %% [markdown]
# # JSON to DataFrame without missing values

# %%
# read in the feature dataframe
path = org.path("02_PlausFeatureList.csv")
feature_df = pd.read_csv(path, sep =";", index_col='names')

# %%
json_df = func.json_to_correct_df("02_LiveData.json", feature_df)

# %%
json_df
# Out:
#                  date     co_gt   pt08_s1_co    c6h6_gt  pt08_s2_nmhc  nox_gt  \
# 0 2005-02-07 00:00:00  3.530000  1107.000000  10.458205    953.579453   550.0
# 1 2005-02-07 01:00:00  2.168604  1557.000000  24.770000    953.579453   550.0
# 2 2005-02-07 02:00:00  2.168604  1098.303412   9.060000    953.579453   550.0
# 3 2005-02-07 03:00:00  2.168604  1098.303412  10.458205    953.579453   550.0
# 4 2005-02-07 04:00:00  2.168604   770.000000  10.458205    953.579453   550.0
# 5 2005-02-07 05:00:00  4.470000  1003.000000  10.458205   1444.000000   550.0
# 6 2005-02-07 06:00:00  2.720000  1407.000000  10.458205    953.579453   437.0
# 7 2005-02-07 07:00:00  2.168604   871.000000  10.458205    953.579453   437.0
# 8 2005-02-07 08:00:00  3.620000   662.000000  10.458205   1693.000000   300.0
#
#    pt08_s3_nox      no2_gt  pt08_s4_no2  pt08_s5_o3      t     rh    ah
# 0   848.762615   40.000000       1878.0      1977.0  18.89  46.43  0.61
# ...
